# %% [markdown]
# # 📒 Lekce 08 – Pandas základy
#
# Zápisník z kurzu [Python pro data 1](https://kodim.cz/czechitas/python-data-1) na Kódím.cz.
#
# Témata lekce:
# - načtení dat z CSV (`read_csv`) a JSON (`read_json`)
# - první pohled na DataFrame: `info()`, `shape`, `columns`
# - výběr řádků a sloupců: `iloc`, `loc`

# %%
## 1. Import pandas a načtení CSV
# Out:
# 1.5.0
# module is installed

# %%
import pandas
nakupy = pandas.read_csv("../data/nakupy.csv")
nakupy

# %%
nakupy.info()

# %%
# Pokud by nás třeba zajímal jen počet řádků, napíšeme:
pocet_radku = nakupy.shape[0]
print("Moje data mají " + str(pocet_radku) + " řádků.")

# %%
## 2. Načtení většího datasetu – DataAnalyst.csv

Data o pracovních nabídkách pro datové analytiky (Kaggle dataset).  
`index_col=0` říká pandasu, aby první sloupec použil jako index místo generování vlastního.

# %%
import pandas
jobs = pandas.read_csv("../data/DataAnalyst.csv", index_col=0)
jobs

# %%
jobs.info()

# %%
#jobs.columns
list(jobs.columns)
#print(nakupy.iloc[:, 0].unique())

# %%
#len(jobs)
jobs.shape#[0]

# %%
jobs.iloc[9]# [[9]] vyrobí dataframe

# %%
# iloc – výběr podle pozice (číslo řádku / sloupce)
# iloc[řádky, sloupce] – řezy fungují stejně jako u seznamů
jobs.iloc[11:20]
# jobs.iloc[11:20, 5:11]   # jen vybrané sloupce
# jobs.iloc[11:20]["Location"]  # sloupec podle názvu
